# %% [markdown]
# <a href="https://colab.research.google.com/github/MateoJacomeUPC/BDM/blob/master/BDM_Project_OpenDataIncome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install "dask[complete]"

# %%
import os
from datetime import datetime
import pandas as pd
import dask.dataframe as dd
from pyarrow import fs
import pyarrow.parquet as pq
import pyarrow as pa

# %% [markdown]
# Using Dask with Remote Data
# - https://docs.dask.org/en/latest/how-to/connect-to-remote-data.html
# - https://docs.dask.org/en/latest/generated/dask.dataframe.read_csv.html#dask.dataframe.read_csv

# %%
# returns dataframe for processing to parquet for persistent storage
# needs to return file list so that files can be deleted after processing?
def DaskLoadPartitionedCSV(directory, source):
  """ 
  Input: a string for the data directory path,  
  a string of the source folder name that contains partitioned data in csv format
  Output: dask dataframe, list of loaded files
  """
  path = directory + "/" + source + '/*.csv'
  # loading all csv files in path to a single dask dataframe, adding column for source file
  ddf = dd.read_csv(path, include_path_column='sourceFile', blocksize='64MB')
  # add timestamp to column called 'load_time'
  ddf['load_time'] = datetime.now()
  return ddf

# %% [markdown]
# Setting Datatypes in Dask
# - https://docs.dask.org/en/latest/generated/dask.dataframe.DataFrame.astype.html

# %%
def setSchema(source, ddf):
  """ 
  Input: a string label for the source data,  
  a dask dataframe that has been imported from source files
  Output: dask dataframe that complies with schema
  """
  if source == "opendatabcn-income":
    # set schema using smallest possible datatype
    schema = {
        'Any':'uint16',
        'Codi_Districte':'uint8',
        'Nom_Districte': 'str',
        'Codi_Barri':'uint8',
        'Nom_Barri': 'str',
        'Població':'uint32',
        'Índex RFD Barcelona = 100': 'str',
        'sourceFile': 'str'}
    ddf = ddf.astype(schema)
    # mixed datatype columns must be converted using dd.to_numeric()
    ddf['Índex RFD Barcelona = 100']= dd.to_numeric(ddf['Índex RFD Barcelona = 100'], errors='coerce')
  return ddf

# %%
def getPyarrowTable(source, ddf):
  """ 
  Input: a string label for the source data,  
  a dask dataframe with the correct schema
  Output: pyarrow table that complies with schema
  """
  if source == "opendatabcn-income":
    # set pyarrow schema
    pa_schema = pa.schema([
        ("Any", pa.uint16()),
        ("Codi_Districte", pa.uint8()),
        ("Nom_Districte", pa.string()),
        ("Codi_Barri", pa.uint8()),
        ("Nom_Barri", pa.string()),
        ("Població", pa.uint32()),
        ("Índex RFD Barcelona = 100", pa.float64()),
        ('sourceFile', pa.string()),
        ("load_time", pa.timestamp('ns')) # datetime.now()
        ])
    # convert Dask df to Pandas df 
    df = ddf.compute()
    # sort and set index using Pandas
    df = df.sort_values(by=["Nom_Districte", "Nom_Barri", "Any"])
    df = df.set_index(["Nom_Districte", "Nom_Barri", "Any"])
    # Load Pandas df to pyarrow table using schema
    table = pa.Table.from_pandas(df, schema=pa_schema, preserve_index=True)
  return table

# %% [markdown]
# # Implement persistent load process
#
# Below I call all the functions to import the data.
#
# TO DO: CHECK DIRECTORY FOR EXISTING .PARQUET FILE

# %%
directory = "/content/drive/MyDrive/BDM-Project/Data"
source = "opendatabcn-income"
ddf = DaskLoadPartitionedCSV(directory, source) # load data
ddf = setSchema(source, ddf) # set schema
table = getPyarrowTable(source, ddf) # convert to pyarrow table

# Write a parquet table and collect metadata information
metadata_collector = []
pq.write_table(table, '/content/drive/MyDrive/BDM-Project/Data/opendatabcn-income/opendatabcn-income.parquet', 
               metadata_collector=metadata_collector,
               row_group_size=134217728) #128 mb
# use pq.write_metadata to combine and write metadata in a single step
pq.write_metadata(table.schema, "/content/drive/MyDrive/BDM-Project/Data/opendatabcn-income/_metadata",
    metadata_collector=metadata_collector)

# %% [markdown]
# # Verify written files
#
# Checking the written .parquet files by reading them into a new dataframe

# %%
parquet_file = pq.ParquetFile('/content/drive/MyDrive/BDM-Project/Data/opendatabcn-income/opendatabcn-income.parquet')
metadata = parquet_file.metadata
metadata
# Out:
# <pyarrow._parquet.FileMetaData object at 0x7ff2ff35dd10>
#   created_by: parquet-cpp-arrow version 6.0.1
#   num_columns: 9
#   num_rows: 811
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 5382

# %%
schema = pq.read_schema('/content/drive/MyDrive/BDM-Project/Data/opendatabcn-income/opendatabcn-income.parquet')
schema
# Out:
# Any: uint16
# Codi_Districte: uint8
# Nom_Districte: string
# Codi_Barri: uint8
# Nom_Barri: string
# Població: int64
# Índex RFD Barcelona = 100: double
# sourceFile: string
# load_time: timestamp[us]
# -- schema metadata --
# pandas: '{"index_columns": ["Any", "Nom_Districte", "Nom_Barri"], "column' + 1295

# %%
new_df = pd.read_parquet('/content/drive/MyDrive/BDM-Project/Data/opendatabcn-income/opendatabcn-income.parquet')
new_df.head(20)
# Out:
#                                                           Codi_Districte  \
# Any  Nom_Districte Nom_Barri
# 2007 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2008 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2009 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2010 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2011 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2012 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2013 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2014 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2015 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2016 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2017 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera               1
# 2007 Ciutat Vella  el Barri Gòtic                                      1
# 2008 Ciutat Vella  el Barri Gòtic                                      1
# 2009 Ciutat Vella  el Barri Gòtic                                      1
# 2010 Ciutat Vella  el Barri Gòtic                                      1
# 2011 Ciutat Vella  el Barri Gòtic                                      1
# 2012 Ciutat Vella  el Barri Gòtic                                      1
# 2013 Ciutat Vella  el Barri Gòtic                                      1
# 2014 Ciutat Vella  el Barri Gòtic                                      1
# 2015 Ciutat Vella  el Barri Gòtic                                      1
#
#                                                           Codi_Barri  \
# Any  Nom_Districte Nom_Barri
# 2007 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2008 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2009 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2010 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2011 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2012 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2013 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2014 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2015 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2016 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2017 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera           4
# 2007 Ciutat Vella  el Barri Gòtic                                  2
# 2008 Ciutat Vella  el Barri Gòtic                                  2
# 2009 Ciutat Vella  el Barri Gòtic                                  2
# 2010 Ciutat Vella  el Barri Gòtic                                  2
# 2011 Ciutat Vella  el Barri Gòtic                                  2
# 2012 Ciutat Vella  el Barri Gòtic                                  2
# 2013 Ciutat Vella  el Barri Gòtic                                  2
# 2014 Ciutat Vella  el Barri Gòtic                                  2
# 2015 Ciutat Vella  el Barri Gòtic                                  2
#
#                                                           Població  \
# Any  Nom_Districte Nom_Barri
# 2007 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22572
# 2008 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22649
# 2009 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     23136
# 2010 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     23101
# 2011 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22632
# 2012 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22873
# 2013 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22821
# 2014 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22674
# 2015 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22305
# 2016 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22380
# 2017 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera     22923
# 2007 Ciutat Vella  el Barri Gòtic                            27946
# 2008 Ciutat Vella  el Barri Gòtic                            25556
# 2009 Ciutat Vella  el Barri Gòtic                            21045
# 2010 Ciutat Vella  el Barri Gòtic                            18720
# 2011 Ciutat Vella  el Barri Gòtic                            17257
# 2012 Ciutat Vella  el Barri Gòtic                            16754
# 2013 Ciutat Vella  el Barri Gòtic                            16327
# 2014 Ciutat Vella  el Barri Gòtic                            15911
# 2015 Ciutat Vella  el Barri Gòtic                            15269
#
#                                                           Índex RFD Barcelona = 100  \
# Any  Nom_Districte Nom_Barri
# 2007 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       80.2
# 2008 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       81.8
# 2009 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       88.8
# 2010 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       91.2
# 2011 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       86.1
# 2012 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       89.3
# 2013 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       91.2
# 2014 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       92.5
# 2015 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       96.4
# 2016 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       97.8
# 2017 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera                       99.4
# 2007 Ciutat Vella  el Barri Gòtic                                              86.5
# 2008 Ciutat Vella  el Barri Gòtic                                              80.8
# 2009 Ciutat Vella  el Barri Gòtic                                              94.3
# 2010 Ciutat Vella  el Barri Gòtic                                              92.3
# 2011 Ciutat Vella  el Barri Gòtic                                              98.8
# 2012 Ciutat Vella  el Barri Gòtic                                              99.7
# 2013 Ciutat Vella  el Barri Gòtic                                             103.6
# 2014 Ciutat Vella  el Barri Gòtic                                              98.5
# 2015 Ciutat Vella  el Barri Gòtic                                             108.5
#
#                                                                                                  sourceFile  \
# Any  Nom_Districte Nom_Barri
# 2007 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2008 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2009 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2010 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2011 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2012 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2013 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2014 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2015 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2016 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2017 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera  /content/drive/MyDrive/BDM-Project/Data/openda...
# 2007 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2008 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2009 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2010 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2011 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2012 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2013 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2014 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
# 2015 Ciutat Vella  el Barri Gòtic                         /content/drive/MyDrive/BDM-Project/Data/openda...
#
#                                                                           load_time
# Any  Nom_Districte Nom_Barri
# 2007 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2008 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2009 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2010 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2011 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2012 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2013 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2014 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2015 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2016 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2017 Ciutat Vella  Sant Pere, Santa Caterina i la Ribera 2022-04-04 20:23:38.867772
# 2007 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2008 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2009 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2010 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2011 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2012 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2013 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2014 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
# 2015 Ciutat Vella  el Barri Gòtic                        2022-04-04 20:23:38.867772
